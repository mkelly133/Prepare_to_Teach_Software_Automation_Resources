# %% [markdown]
# # Week 1 - Problem Set
#
# Practice what you learnt today with these problems; I will share the answers on Monday before the next workshop.

# %%
# Run the dependencies before you begin
import numpy as np
import matplotlib.pyplot as plt
from utils_common import compute_model_output

plt.style.use('deeplearning.mplstyle')

# %% [markdown]
# __1. In a markdown block, using MD syntax, create an ordered list of 4 different features that could be used to predict house prices.__

# %% [markdown]
# 1. Block size
# 2. Number of bedrooms
# 3. Year of construction
# 4. Neighbouring sale prices

# %% [markdown]
# __2. In a code block, convert the following table to a Python List, Numpy array and a Pandas DataFrame.__
#
# | Student Number | Student Name | Result |
# | --- | --- | --- |
# | 1234 | Ben | 99 |
# | 1235 | Jess | 85 |
# | 1236 | Janet | 50 |
# | 1237 | Kevin | 62 |
# | 1238 | Nick | 41 |

# %%
table_list = [["Student Number", "Student Name", "Result"],[1234,"Ben",99],[1234,"Jess",85],[1234,"Janet",50],[1234,"Kevin",62],[1234,"Nick",41]]
table_np = np.array(table_list)
import pandas as pd
table_df = pd.DataFrame(table_list)
print("Python List\n",table_list, "\n\n Numpy Array\n", table_np, "\n\n Pandas Dataframe \n", table_df)
# Out:
# Python List
#  [['Student Number', 'Student Name', 'Result'], [1234, 'Ben', 99], [1234, 'Jess', 85], [1234, 'Janet', 50], [1234, 'Kevin', 62], [1234, 'Nick', 41]]
#
#  Numpy Array
#  [['Student Number' 'Student Name' 'Result']
#  ['1234' 'Ben' '99']
#  ['1234' 'Jess' '85']
#  ['1234' 'Janet' '50']
#  ['1234' 'Kevin' '62']
#  ['1234' 'Nick' '41']]
#
#  Pandas Dataframe
#                  0             1       2
# 0  Student Number  Student Name  Result
# 1            1234           Ben      99
# 2            1234          Jess      85
# 3            1234         Janet      50
# 4            1234         Kevin      62
# 5            1234          Nick      41

# %% [markdown]
# __3. In a markdown block, select and justify one of the three data structures for use in Machine Learning.__

# %% [markdown]
# For ML, a Pandas Dataframe is most flexible (though for ease of use, a NumPy array could be handy sometimes too.)

# %% [markdown]
# __4. In a markdown block, outline the Machine Learning Linear Regression algorithm.__

# %% [markdown]
# A linear regression model explains the response of one variable based on one or more other variables. In ML, a linear regression algorithm could explain a simple relationship between variables, using computation to determine the relevant coefficients to best fit the data.

# %% [markdown]
# __5. Modify the code block below to adjust $m$ and $b$ to manually fit a Linear Regression line with good intuition or fit.__

# %%
x_train = np.array([[-4], [-8], [-10], [-12], [-14]])
y_train = np.array([1, 3, 5, 7, 9])

m = -1
b = -4.5

tmp_f_mb = compute_model_output(x_train, m, b,)

plt.plot(x_train, tmp_f_mb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.show()

# %% [markdown]
# __6. Modify the above code to add a legend, title, Xaxis title and Yaxis title to the MatPlotLib in question 5.__

# %%
plt.plot(x_train, tmp_f_mb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.legend()
plt.xlabel('X Axis')
plt.ylabel('Y Label')
plt.title('Title')
plt.show()

# %% [markdown]
# __7. Refering to the below model, describe underfitting in Linear Regression.__

# %% [markdown]
# Capturing the majority of values will underfit the outlier, capturing the outlier will underfit the other values, and capturing all will overfit. Need to clean the data before training the model.

# %% [markdown]
# __8. In a markdown block, identify and explain the biggest issue with this dataset if it were to be used to train a Linear Regression model.__
#
# ```python
# x_train = np.array([1000, 1500, 1800, 2000, 2200])
# y_train = np.array([[200000], [250000], [260000], [280000], [500000]])
# ```

# %% [markdown]
# As demonstrated below, linear regression can't effectively capture the apparent outlier.

# %%
x_train2 = np.array([1000, 1500, 1800, 2000, 2200])
y_train2 = np.array([[200000], [250000], [260000], [280000], [500000]])

m = 60
b = 150000
m2 = 200
b2 = 5000

tmp_f_mb = compute_model_output(x_train2, m, b,)
tmp_f_mb2 = compute_model_output(x_train2, m2, b2,)
plt.plot(x_train2, tmp_f_mb, c='b',label='Our Prediction')
plt.plot(x_train2, tmp_f_mb2, c='g',label='Our Other Prediction')
plt.scatter(x_train2, y_train2, marker='x', c='r',label='Actual Values')
plt.legend()
plt.show()

# %% [markdown]
# __9. Play the [Gradient Descent Game](https://www.i-am.ai/gradient-descent.html), and read about local and global minimums.__
